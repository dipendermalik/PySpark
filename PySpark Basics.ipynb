# %% [markdown]
# ## 1. PySpark first impression using Colab

# %%
# Download Java and Spark

# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://archive.apache.org/dist/spark/spark-3.2.1/spark-3.2.1-bin-hadoop3.2.tgz
# !tar xf spark-3.2.1-bin-hadoop3.2.tgz
# !pip install -q findspark

# %%
# Set up the paths

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.2.1-bin-hadoop3.2"

# %%
# Create a Spark session

import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark.conf.set("spark.sql.caseSensitive", True) # Avoid error "Found duplicate column(s) in the data schema"
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://6cd9b45e92e7:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### 1.0 Import data from csv

# %%
# Upload 'Airline-Sentiment.csv' to the runtime.
# Note that the data will be deleted automatically if the runtime is inactive for a while.

# Load the csv into a dataframe
myDF = spark.read.csv("Airline-Sentiment.csv",header=True,encoding='latin1',escape="\"",multiLine=True)

# %%
# Take a look

myDF.show()
# Out:
# +-----------------+--------------+-------------+--------------------+-----------+-------------+--------------------+--------------------+
# |airline_sentiment|       airline|retweet_count|                text|tweet_coord|tweet_created|      tweet_location|       user_timezone|
# +-----------------+--------------+-------------+--------------------+-----------+-------------+--------------------+--------------------+
# |          neutral|Virgin America|            0|@VirginAmerica Wh...|       null|2/24/15 11:35|                null|Eastern Time (US ...|
# |         positive|Virgin America|            0|@VirginAmerica pl...|       null|2/24/15 11:15|                null|Pacific Time (US ...|
# |          neutral|Virgin America|            0|@VirginAmerica I ...|       null|2/24/15 11:15|           Lets Play|Central Time (US ...|
# |         negative|Virgin America|            0|@VirginAmerica it...|       null|2/24/15 11:15|                null|Pacific Time (US ...|
# |         negative|Virgin America|            0|@VirginAmerica an...|       null|2/24/15 11:14|                null|Pacific Time (US ...|
# |         negative|Virgin America|            0|@VirginAmerica se...|       null|2/24/15 11:14|                null|Pacific Time (US ...|
# |         positive|Virgin America|            0|@VirginAmerica ye...|       null|2/24/15 11:13|    San Francisco CA|Pacific Time (US ...|
# |          neutral|Virgin America|            0|@VirginAmerica Re...|       null|2/24/15 11:12|         Los Angeles|Pacific Time (US ...|
# |         positive|Virgin America|            0|@virginamerica We...|       null|2/24/15 11:11|           San Diego|Pacific Time (US ...|
# |         positive|Virgin America|            0|@VirginAmerica it...|       null|2/24/15 10:53|         Los Angeles|Eastern Time (US ...|
# |          neutral|Virgin America|            0|@VirginAmerica di...|       null|2/24/15 10:48|     1/1 loner squad|Eastern Time (US ...|
# |         positive|Virgin America|            0|@VirginAmerica I ...|       null|2/24/15 10:30|                 NYC|    America/New_York|
# |         positive|Virgin America|            0|@VirginAmerica Th...|       null|2/24/15 10:30|                 NYC|    America/New_York|
# |         positive|Virgin America|            0|@VirginAmerica @v...|       null|2/24/15 10:21|                null|Eastern Time (US ...|
# |         positive|Virgin America|            0|@VirginAmerica Th...|       null|2/24/15 10:15|   San Francisco, CA|Pacific Time (US ...|
# |         negative|Virgin America|            0|@VirginAmerica SF...|       null|2/24/15 10:01|       palo alto, ca|Pacific Time (US ...|
# |         positive|Virgin America|            0|@VirginAmerica So...|       null| 2/24/15 9:42|         west covina|Pacific Time (US ...|
# |         negative|Virgin America|            0|@VirginAmerica  I...|       null| 2/24/15 9:39|this place called...|Eastern Time (US ...|
# |         positive|Virgin America|            0|I _ü flying @...|       null| 2/24/15 9:15|Somewhere celebra...|Atlantic Time (Ca...|
# |         positive|Virgin America|            0|@VirginAmerica yo...|       null| 2/24/15 9:04|    Boston | Waltham|               Quito|
# +-----------------+--------------+-------------+--------------------+-----------+-------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Check the type

type(myDF)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
# Check the total number of rows

myDF.count()
# Out:
# 14640

# %%
# Understand the data types of each column

myDF.printSchema()
# Out:
# root
#  |-- airline_sentiment: string (nullable = true)
#  |-- airline: string (nullable = true)
#  |-- retweet_count: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- tweet_coord: string (nullable = true)
#  |-- tweet_created: string (nullable = true)
#  |-- tweet_location: string (nullable = true)
#  |-- user_timezone: string (nullable = true)

# %%
# Subset dataframe by columns

myDF.select(["airline","airline_sentiment"]).show()
# Out:
# +--------------+-----------------+
# |       airline|airline_sentiment|
# +--------------+-----------------+
# |Virgin America|          neutral|
# |Virgin America|         positive|
# |Virgin America|          neutral|
# |Virgin America|         negative|
# |Virgin America|         negative|
# |Virgin America|         negative|
# |Virgin America|         positive|
# |Virgin America|          neutral|
# |Virgin America|         positive|
# |Virgin America|         positive|
# |Virgin America|          neutral|
# |Virgin America|         positive|
# |Virgin America|         positive|
# |Virgin America|         positive|
# |Virgin America|         positive|
# |Virgin America|         negative|
# |Virgin America|         positive|
# |Virgin America|         negative|
# |Virgin America|         positive|
# |Virgin America|         positive|
# +--------------+-----------------+
# only showing top 20 rows

# %%
# Get all the airlines names

airlines = myDF.select("airline").distinct()
airlines.show()
# Out:
# +--------------+
# |       airline|
# +--------------+
# |         Delta|
# |Virgin America|
# |        United|
# |    US Airways|
# |     Southwest|
# |      American|
# +--------------+

# %%
# Count number of tweets per airline

tweetsPerAirline = myDF.groupBy("airline").count()
tweetsPerAirline.show()
# Out:
# +--------------+-----+
# |       airline|count|
# +--------------+-----+
# |         Delta| 2222|
# |Virgin America|  504|
# |        United| 3822|
# |    US Airways| 2913|
# |     Southwest| 2420|
# |      American| 2759|
# +--------------+-----+

# %%
# GroupBy multiple columns

myDF.groupBy("airline","airline_sentiment").count().show()
# Out:
# +--------------+-----------------+-----+
# |       airline|airline_sentiment|count|
# +--------------+-----------------+-----+
# |     Southwest|         negative| 1186|
# |      American|         negative| 1960|
# |Virgin America|          neutral|  171|
# |    US Airways|          neutral|  381|
# |        United|         positive|  492|
# |    US Airways|         negative| 2263|
# |      American|         positive|  336|
# |         Delta|         negative|  955|
# |Virgin America|         positive|  152|
# |     Southwest|          neutral|  664|
# |        United|          neutral|  697|
# |     Southwest|         positive|  570|
# |         Delta|         positive|  544|
# |         Delta|          neutral|  723|
# |    US Airways|         positive|  269|
# |        United|         negative| 2633|
# |      American|          neutral|  463|
# |Virgin America|         negative|  181|
# +--------------+-----------------+-----+

# %% [markdown]
# ### <font color=blue>Use groupBy to show the number of tweets per sentiment category (i.e., positive, negative, neutral)</font>

# %%
myDF.groupBy("airline_sentiment").count().show()
# Out:
# +-----------------+-----+
# |airline_sentiment|count|
# +-----------------+-----+
# |         positive| 2363|
# |          neutral| 3099|
# |         negative| 9178|
# +-----------------+-----+

# %% [markdown]
# ### <font color=blue>Sort by airlines and then by sentiments for the results returned by myDF.groupBy("airline","airline_sentiment").count().show()</font>

# %%
# Simply use orderBy

myDF.groupBy("airline","airline_sentiment").count().orderBy("airline","airline_sentiment").show()
# Out:
# +--------------+-----------------+-----+
# |       airline|airline_sentiment|count|
# +--------------+-----------------+-----+
# |      American|         negative| 1960|
# |      American|          neutral|  463|
# |      American|         positive|  336|
# |         Delta|         negative|  955|
# |         Delta|          neutral|  723|
# |         Delta|         positive|  544|
# |     Southwest|         negative| 1186|
# |     Southwest|          neutral|  664|
# |     Southwest|         positive|  570|
# |    US Airways|         negative| 2263|
# |    US Airways|          neutral|  381|
# |    US Airways|         positive|  269|
# |        United|         negative| 2633|
# |        United|          neutral|  697|
# |        United|         positive|  492|
# |Virgin America|         negative|  181|
# |Virgin America|          neutral|  171|
# |Virgin America|         positive|  152|
# +--------------+-----------------+-----+

# %% [markdown]
# ### 1.1 Import data from json

# %% [markdown]
# ### Please go to https://nijianmo.github.io/amazon/index.html and download the review data for "Magazine Subscriptions" (5-core, 2,375 reviews). Please then upload this file to the Colab runtime before running the code below.

# %%
# Compressed json file can be read directly with spark!

myReview = spark.read.json("Magazine_Subscriptions_5.json.gz")

# %%
# Take a look

myReview.show()
# Out:
# +----------+-----+-------+--------------------+-----------+--------------+------------------+-----------------+--------------------+--------------+--------+----+
# |      asin|image|overall|          reviewText| reviewTime|    reviewerID|      reviewerName|            style|             summary|unixReviewTime|verified|vote|
# +----------+-----+-------+--------------------+-----------+--------------+------------------+-----------------+--------------------+--------------+--------+----+
# |B00005N7P0| null|    4.0|I'm old, and so i...|02 26, 2014| A5QQOOZJOVPSF| John L. Mehlmauer|             null|   Cheapskates guide|    1393372800|    true|null|
# |B00005N7PS| null|    5.0|There's nothing t...| 03 6, 2004| A5RHZE7B8SV5Q|    gorillazfan249|             null|The best mature M...|    1078531200|   false|   3|
# |B00005N7PS| null|    1.0|If you're the kin...|07 15, 2003| A1RPTVW5VEOSI|Michael J. Edelman|             null|THE Magazine for ...|    1058227200|   false|  17|
# |B00005N7PS| null|    1.0|Nothing to it.  J...|01 31, 2015|A1SFRBCMW8XVBW| Hoyett L. Barnett|             null|Nothing to it. Ju...|    1422662400|    true|null|
# |B00005N7P0| null|    5.0|When PC Magazine ...| 10 5, 2010|A1IU9VPCBKZPE8|      Randolph Eck|             null|Excellent Compute...|    1286236800|    true|   2|
# |B00005N7PS| null|    4.0|Details is much l...|10 21, 2008| AG6TX1ZJHLMO7|       W. Dietrich|             null|A toned down GQ /...|    1224547200|   false|   2|
# |B00005N7P0| null|    5.0|In my mind BEST P...|02 25, 2009|A3OIE7IE9LTPJG|          GatorMan|             null|    Best PC Magazine|    1235520000|    true|null|
# |B00005N7PS| null|    3.0|Details is a mild...|03 15, 2006|A3JPFWKS83R49V|       Bryan Carey|             null| Give Me the Details|    1142380800|   false|  98|
# |B00005N7P0| null|    4.0|Maximum PC is a m...|09 24, 2007|A3JPFWKS83R49V|       Bryan Carey|             null|Maximizing Electr...|    1190592000|   false|   2|
# |B00005N7P0| null|    1.0|Maximum PC's slog...| 03 9, 2004| A5RHZE7B8SV5Q|    gorillazfan249|             null|More like half an...|    1078790400|   false|   5|
# |B00005N7QC| null|    5.0|I love glamour ma...|06 12, 2017|A2VRQ8RNTKY1XT|    Barbara M. Fox|{ Kindle Edition}|      Great magazine|    1497225600|    true|null|
# |B00005N7OV| null|    4.0|This magazine has...|10 17, 2003| AQ8DU6XVA3USJ|  Alejandra Vernon|{ Print Magazine}|  cluttered but nice|    1066348800|   false|  27|
# |B00005N7OV| null|    5.0|Having the honor ...|07 16, 2002|A2JJGIJI8X6KRS|         Psboston7|{ Print Magazine}|You can never go ...|    1026777600|   false|   2|
# |B00005N7OV| null|    5.0|If you are lookin...|12 30, 2001|A281NPSIMI1C2R| Rebecca of Amazon|{ Print Magazine}|Essential for Dec...|    1009670400|   false|   5|
# |B00005N7RD| null|    5.0|I buy this for my...|06 14, 2002|A281NPSIMI1C2R| Rebecca of Amazon|{ Print Magazine}|Women buy this to...|    1024012800|   false|  16|
# |B00005N7Q1| null|    4.0|I love the magazi...|04 15, 2017|A3AFOX1G1FZ3CC|       Scott Burns|{ Print Magazine}|          Four Stars|    1492214400|    true|null|
# |B00005N7QC| null|    5.0|    love my magazine|04 14, 2016| AXH102X1MH953|   Amazon Customer|{ Kindle Edition}|             Love it|    1460592000|   false|null|
# |B00005N7QC| null|    5.0|                 Fun|04 13, 2015|A1COZPXWL7Q7WJ| Christopher Snell|{ Print Magazine}|          Five Stars|    1428883200|    true|null|
# |B00005N7RD| null|    5.0|Great articles .....|03 12, 2018|A3MQ98LDJDY2V5|         JanLayMay|{ Print Magazine}|        Motivational|    1520812800|    true|null|
# |B00005N7RD| null|    5.0|    It's a man thing|02 22, 2018|A1CCUTTNJJRWLQ|   Amazon Customer|{ Print Magazine}|    It's a man thing|    1519257600|    true|null|
# +----------+-----+-------+--------------------+-----------+--------------+------------------+-----------------+--------------------+--------------+--------+----+
# only showing top 20 rows

# %%
# Check the total number of rows

myReview.count()
# Out:
# 2375

# %%
# Understand the data types of each column

myReview.printSchema()
# Out:
# root
#  |-- asin: string (nullable = true)
#  |-- image: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- overall: double (nullable = true)
#  |-- reviewText: string (nullable = true)
#  |-- reviewTime: string (nullable = true)
#  |-- reviewerID: string (nullable = true)
#  |-- reviewerName: string (nullable = true)
#  |-- style: struct (nullable = true)
#  |    |-- Format:: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- unixReviewTime: long (nullable = true)
#  |-- verified: boolean (nullable = true)
#  |-- vote: string (nullable = true)

# %%
# Subset dataframe by rows
# SQL can be supplied as string input for where() function

# Return the reviews with rating >= 4.0
myReview.where("overall >= 4").show()
# Out:
# +----------+-----+-------+--------------------+-----------+--------------+-----------------+-----------------+--------------------+--------------+--------+----+
# |      asin|image|overall|          reviewText| reviewTime|    reviewerID|     reviewerName|            style|             summary|unixReviewTime|verified|vote|
# +----------+-----+-------+--------------------+-----------+--------------+-----------------+-----------------+--------------------+--------------+--------+----+
# |B00005N7P0| null|    4.0|I'm old, and so i...|02 26, 2014| A5QQOOZJOVPSF|John L. Mehlmauer|             null|   Cheapskates guide|    1393372800|    true|null|
# |B00005N7PS| null|    5.0|There's nothing t...| 03 6, 2004| A5RHZE7B8SV5Q|   gorillazfan249|             null|The best mature M...|    1078531200|   false|   3|
# |B00005N7P0| null|    5.0|When PC Magazine ...| 10 5, 2010|A1IU9VPCBKZPE8|     Randolph Eck|             null|Excellent Compute...|    1286236800|    true|   2|
# |B00005N7PS| null|    4.0|Details is much l...|10 21, 2008| AG6TX1ZJHLMO7|      W. Dietrich|             null|A toned down GQ /...|    1224547200|   false|   2|
# |B00005N7P0| null|    5.0|In my mind BEST P...|02 25, 2009|A3OIE7IE9LTPJG|         GatorMan|             null|    Best PC Magazine|    1235520000|    true|null|
# |B00005N7P0| null|    4.0|Maximum PC is a m...|09 24, 2007|A3JPFWKS83R49V|      Bryan Carey|             null|Maximizing Electr...|    1190592000|   false|   2|
# |B00005N7QC| null|    5.0|I love glamour ma...|06 12, 2017|A2VRQ8RNTKY1XT|   Barbara M. Fox|{ Kindle Edition}|      Great magazine|    1497225600|    true|null|
# |B00005N7OV| null|    4.0|This magazine has...|10 17, 2003| AQ8DU6XVA3USJ| Alejandra Vernon|{ Print Magazine}|  cluttered but nice|    1066348800|   false|  27|
# |B00005N7OV| null|    5.0|Having the honor ...|07 16, 2002|A2JJGIJI8X6KRS|        Psboston7|{ Print Magazine}|You can never go ...|    1026777600|   false|   2|
# |B00005N7OV| null|    5.0|If you are lookin...|12 30, 2001|A281NPSIMI1C2R|Rebecca of Amazon|{ Print Magazine}|Essential for Dec...|    1009670400|   false|   5|
# |B00005N7RD| null|    5.0|I buy this for my...|06 14, 2002|A281NPSIMI1C2R|Rebecca of Amazon|{ Print Magazine}|Women buy this to...|    1024012800|   false|  16|
# |B00005N7Q1| null|    4.0|I love the magazi...|04 15, 2017|A3AFOX1G1FZ3CC|      Scott Burns|{ Print Magazine}|          Four Stars|    1492214400|    true|null|
# |B00005N7QC| null|    5.0|    love my magazine|04 14, 2016| AXH102X1MH953|  Amazon Customer|{ Kindle Edition}|             Love it|    1460592000|   false|null|
# |B00005N7QC| null|    5.0|                 Fun|04 13, 2015|A1COZPXWL7Q7WJ|Christopher Snell|{ Print Magazine}|          Five Stars|    1428883200|    true|null|
# |B00005N7RD| null|    5.0|Great articles .....|03 12, 2018|A3MQ98LDJDY2V5|        JanLayMay|{ Print Magazine}|        Motivational|    1520812800|    true|null|
# |B00005N7RD| null|    5.0|    It's a man thing|02 22, 2018|A1CCUTTNJJRWLQ|  Amazon Customer|{ Print Magazine}|    It's a man thing|    1519257600|    true|null|
# |B00005N7RD| null|    5.0|Husband loves the...| 02 9, 2018|A346KIAJ2MI38D|      Unicorn Mom|{ Print Magazine}|  Great guy magazine|    1518134400|    true|null|
# |B00005N7OV| null|    5.0|Another great mag...|03 23, 2018|A1SYEK1CRS9FAA|     Nancy Wahlen|{ Print Magazine}|Another great mag...|    1521763200|    true|null|
# |B00005N7QC| null|    5.0|For me, Glamour m...| 01 3, 2014| AQ2S1QAI4R2V6|           Mindyx|{ Kindle Edition}|          Great Mag!|    1388707200|   false|null|
# |B00005N7QC| null|    5.0|The item came in ...|02 28, 2013| AXV3OJG9BZ2JW|        DoomsDay3|{ Print Magazine}|               great|    1362009600|    true|null|
# +----------+-----+-------+--------------------+-----------+--------------+-----------------+-----------------+--------------------+--------------+--------+----+
# only showing top 20 rows

# %%
# Another example counting how many reviews for a particular product
# Don't forget the quotes within the statement quotes

myReview.where("asin = 'B00005N7P0'").count()
# Out:
# 6

# %%
# More operations are available from Spark's SQL functions

from pyspark.sql import functions as f

# %%
# A slightly more complicated one, but very informative
# It shows how many reviews are provided by each unique reviewer and their average ratings.
# Note that in Python you can break lines within brackets for better visual

myReview.groupBy("reviewerID").agg(
    f.collect_set("asin").alias("products"),
    f.count("asin").alias("num_reviews"),
    f.avg("overall").alias("rating")
).sort("num_reviews",ascending=False).show()
# Out:
# +--------------+--------------------+-----------+------------------+
# |    reviewerID|            products|num_reviews|            rating|
# +--------------+--------------------+-----------+------------------+
# |A3JPFWKS83R49V|[B00005N7QI, B000...|         30|3.7333333333333334|
# |A2OTUWUSH49XIN|[B000W3MB5M, B000...|         20|              3.95|
# |A3GA09FYFKL4EY|[B00005N7TB, B000...|         19|3.6842105263157894|
# | AA14AMM03HMXW|[B001LF4EVO, B000...|         19|3.6842105263157894|
# | AVF9FV7AMRP5C|[B00007AX0N, B000...|         19| 4.052631578947368|
# | AKMEY1BSHSDG7|[B001LF4EVO, B000...|         18|               4.5|
# | A8N76G7E26DM4|[B00005NIN8, B000...|         16|            3.5625|
# |A2BSKT65F16LAQ|[B000XXDJ70, B000...|         15|               4.8|
# |A21FFUC8BEMDJ7|[B00005N7PN, B000...|         14| 4.785714285714286|
# |A281NPSIMI1C2R|[B00005N7SL, B000...|         14| 4.857142857142857|
# | AXV3OJG9BZ2JW|[B00005N7TG, B000...|         13|               5.0|
# |A1PGC1GEBY9CZU|[B000069YW9, B000...|         13| 4.076923076923077|
# | AAB2UG7X51G0D|[B00006LKH1, B000...|         13|4.6923076923076925|
# |A35KTWDOK0EXMY|[B00005R8BA, B000...|         12|               5.0|
# |A2H3JURQZOHVMB|[B00005R8BA, B000...|         12|               5.0|
# | A1RPTVW5VEOSI|[B00005N7PS, B000...|         12|2.4166666666666665|
# |A2LI10MAXV0815|[B00005N7PN, B000...|         12|               5.0|
# | A3E90BH4019TC|[B000IOEJ8W, B000...|         12|3.4166666666666665|
# | AAZV7DET3J15U|[B00005R8BA, B000...|         12|               5.0|
# |A3H04WG2JTEY4C|[B000XXDJ70, B000...|         12|               4.5|
# +--------------+--------------------+-----------+------------------+
# only showing top 20 rows

# %% [markdown]
# ### <font color=blue>Summarise the average ratings for each unique product/asin in the year 2014.</font>

# %%
# Subset by filtering for the year 2014
mySet = myReview.where(f.col("reviewTime").contains("2014"))

# Now summarise the average ratings for each product
mySet.groupBy("asin").agg(
    f.count("overall").alias("num_reviews"),
    f.avg("overall").alias("rating")
).sort("num_reviews",ascending=False).show()
# Out:
# +----------+-----------+------------------+
# |      asin|num_reviews|            rating|
# +----------+-----------+------------------+
# |B00005N7OV|         14| 4.642857142857143|
# |B000ILY9LW|         13| 4.769230769230769|
# |B00005N7QG|         10|               4.3|
# |B00005N7PN|         10|               4.7|
# |B000IJ84F6|         10|               4.7|
# |B00005NIOO|          9| 3.888888888888889|
# |B00007B10Y|          9| 4.777777777777778|
# |B000OPOEEE|          9| 3.888888888888889|
# |B00005R8BR|          9| 4.555555555555555|
# |B001LF4EVO|          8|              4.75|
# |B00005NIOH|          8|              4.75|
# |B0037STB02|          8|             4.625|
# |B000IJ7RQ8|          8|             4.625|
# |B01CF3ECNK|          7|3.7142857142857144|
# |B00005N7SG|          7|3.7142857142857144|
# |B000FTJ7JQ|          7|3.7142857142857144|
# |B000IOE9Y6|          6| 4.833333333333333|
# |B00EVV77A0|          5|               5.0|
# |B0001MS2D4|          5|               5.0|
# |B00005N7RA|          5|               4.0|
# +----------+-----------+------------------+
# only showing top 20 rows

# %% [markdown]
# ## 2. PySpark dataframe operations

# %%
# Again make sure 'Airline-Sentiment.csv' is in the runtime.

# Load the csv into a dataframe
# This time we add "inferSchema=True" so that "retweet_count" is recognised as integer type
mySparkDF = spark.read.csv("Airline-Sentiment.csv",header=True,encoding='latin1',escape="\"",multiLine=True,inferSchema=True)
mySparkDF.show(5)
# Out:
# +-----------------+--------------+-------------+--------------------+-----------+-------------+--------------+--------------------+
# |airline_sentiment|       airline|retweet_count|                text|tweet_coord|tweet_created|tweet_location|       user_timezone|
# +-----------------+--------------+-------------+--------------------+-----------+-------------+--------------+--------------------+
# |          neutral|Virgin America|            0|@VirginAmerica Wh...|       null|2/24/15 11:35|          null|Eastern Time (US ...|
# |         positive|Virgin America|            0|@VirginAmerica pl...|       null|2/24/15 11:15|          null|Pacific Time (US ...|
# |          neutral|Virgin America|            0|@VirginAmerica I ...|       null|2/24/15 11:15|     Lets Play|Central Time (US ...|
# |         negative|Virgin America|            0|@VirginAmerica it...|       null|2/24/15 11:15|          null|Pacific Time (US ...|
# |         negative|Virgin America|            0|@VirginAmerica an...|       null|2/24/15 11:14|          null|Pacific Time (US ...|
# +-----------------+--------------+-------------+--------------------+-----------+-------------+--------------+--------------------+
# only showing top 5 rows

# %%
# Produce summary statistics

mySparkDF.describe("retweet_count")
# Out:
# +-------+-------------------+
# |summary|      retweet_count|
# +-------+-------------------+
# |  count|              14640|
# |   mean|0.08265027322404371|
# | stddev| 0.7457781608465299|
# |    min|                  0|
# |    max|                 44|
# +-------+-------------------+

# %%
# Previously we used "printSchema" to show data types
# Below is another way to show data types for each column

mySparkDF.dtypes
# Out:
# [('airline_sentiment', 'string'),
#  ('airline', 'string'),
#  ('retweet_count', 'int'),
#  ('text', 'string'),
#  ('tweet_coord', 'string'),
#  ('tweet_created', 'string'),
#  ('tweet_location', 'string'),
#  ('user_timezone', 'string')]

# %%
# Get the columns

mySparkDF.columns
# Out:
# ['airline_sentiment',
#  'airline',
#  'retweet_count',
#  'text',
#  'tweet_coord',
#  'tweet_created',
#  'tweet_location',
#  'user_timezone']

# %%
# Get a single column
# Add truncate=False to show more content

mySparkDF.select('text').show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------+
# |text                                                                                                                                        |
# +--------------------------------------------------------------------------------------------------------------------------------------------+
# |@VirginAmerica What @dhepburn said.                                                                                                         |
# |@VirginAmerica plus you've added commercials to the experience... tacky.                                                                    |
# |@VirginAmerica I didn't today... Must mean I need to take another trip!                                                                     |
# |@VirginAmerica it's really aggressive to blast obnoxious "entertainment" in your guests' faces &amp; they have little recourse              |
# |@VirginAmerica and it's a really big bad thing about it                                                                                     |
# |@VirginAmerica seriously would pay $30 a flight for seats that didn't have this playing.\nit's really the only bad thing about flying VA    |
# |@VirginAmerica yes, nearly every time I fly VX this ÛÏear wormÛ wonÛªt go away :)                                                       |
# |@VirginAmerica Really missed a prime opportunity for Men Without Hats parody, there. https://t.co/mWpG7grEZP                                |
# |@virginamerica Well, I didn'tÛ_but NOW I DO! :-D                                                                                           |
# |@VirginAmerica it was amazing, and arrived an hour early. You're too good to me.                                                            |
# |@VirginAmerica did you know that suicide is the second leading cause of death among teens 10-24                                             |
# |@VirginAmerica I &lt;3 pretty graphics. so much better than minimal iconography. :D                                                         |
# |@VirginAmerica This is such a great deal! Already thinking about my 2nd trip to @Australia &amp; I haven't even gone on my 1st trip yet! ;p |
# |@VirginAmerica @virginmedia I'm flying your #fabulous #Seductive skies again! U take all the #stress away from travel http://t.co/ahlXHhKiyn|
# |@VirginAmerica Thanks!                                                                                                                      |
# |@VirginAmerica SFO-PDX schedule is still MIA.                                                                                               |
# |@VirginAmerica So excited for my first cross country flight LAX to MCO I've heard nothing but great things about Virgin America. #29DaysToGo|
# |@VirginAmerica  I flew from NYC to SFO last week and couldn't fully sit in my seat due to two large gentleman on either side of me. HELP!   |
# |I _ü flying @VirginAmerica. ÷¼ü_ÙÔ                                                                                                  |
# |@VirginAmerica you know what would be amazingly awesome? BOS-FLL PLEASE!!!!!!! I want to fly with only you.                                 |
# +--------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
# Rename a column

mySparkDF.withColumnRenamed("text", "tweet").show()
# Out:
# +-----------------+--------------+-------------+--------------------+-----------+-------------+--------------------+--------------------+
# |airline_sentiment|       airline|retweet_count|               tweet|tweet_coord|tweet_created|      tweet_location|       user_timezone|
# +-----------------+--------------+-------------+--------------------+-----------+-------------+--------------------+--------------------+
# |          neutral|Virgin America|            0|@VirginAmerica Wh...|       null|2/24/15 11:35|                null|Eastern Time (US ...|
# |         positive|Virgin America|            0|@VirginAmerica pl...|       null|2/24/15 11:15|                null|Pacific Time (US ...|
# |          neutral|Virgin America|            0|@VirginAmerica I ...|       null|2/24/15 11:15|           Lets Play|Central Time (US ...|
# |         negative|Virgin America|            0|@VirginAmerica it...|       null|2/24/15 11:15|                null|Pacific Time (US ...|
# |         negative|Virgin America|            0|@VirginAmerica an...|       null|2/24/15 11:14|                null|Pacific Time (US ...|
# |         negative|Virgin America|            0|@VirginAmerica se...|       null|2/24/15 11:14|                null|Pacific Time (US ...|
# |         positive|Virgin America|            0|@VirginAmerica ye...|       null|2/24/15 11:13|    San Francisco CA|Pacific Time (US ...|
# |          neutral|Virgin America|            0|@VirginAmerica Re...|       null|2/24/15 11:12|         Los Angeles|Pacific Time (US ...|
# |         positive|Virgin America|            0|@virginamerica We...|       null|2/24/15 11:11|           San Diego|Pacific Time (US ...|
# |         positive|Virgin America|            0|@VirginAmerica it...|       null|2/24/15 10:53|         Los Angeles|Eastern Time (US ...|
# |          neutral|Virgin America|            0|@VirginAmerica di...|       null|2/24/15 10:48|     1/1 loner squad|Eastern Time (US ...|
# |         positive|Virgin America|            0|@VirginAmerica I ...|       null|2/24/15 10:30|                 NYC|    America/New_York|
# |         positive|Virgin America|            0|@VirginAmerica Th...|       null|2/24/15 10:30|                 NYC|    America/New_York|
# |         positive|Virgin America|            0|@VirginAmerica @v...|       null|2/24/15 10:21|                null|Eastern Time (US ...|
# |         positive|Virgin America|            0|@VirginAmerica Th...|       null|2/24/15 10:15|   San Francisco, CA|Pacific Time (US ...|
# |         negative|Virgin America|            0|@VirginAmerica SF...|       null|2/24/15 10:01|       palo alto, ca|Pacific Time (US ...|
# |         positive|Virgin America|            0|@VirginAmerica So...|       null| 2/24/15 9:42|         west covina|Pacific Time (US ...|
# |         negative|Virgin America|            0|@VirginAmerica  I...|       null| 2/24/15 9:39|this place called...|Eastern Time (US ...|
# |         positive|Virgin America|            0|I _ü flying @...|       null| 2/24/15 9:15|Somewhere celebra...|Atlantic Time (Ca...|
# |         positive|Virgin America|            0|@VirginAmerica yo...|       null| 2/24/15 9:04|    Boston | Waltham|               Quito|
# +-----------------+--------------+-------------+--------------------+-----------+-------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Where as an alias of filter

mySparkDF.where("retweet_count > 1").count()
# Out:
# 127

# %%
# Try with filter

mySparkDF.filter("retweet_count > 1").orderBy("retweet_count",ascending=False).show()
# Out:
# +-----------------+----------+-------------+--------------------+-----------+-------------+--------------------+--------------------+
# |airline_sentiment|   airline|retweet_count|                text|tweet_coord|tweet_created|      tweet_location|       user_timezone|
# +-----------------+----------+-------------+--------------------+-----------+-------------+--------------------+--------------------+
# |         negative|US Airways|           44|@USAirways 5 hr f...|       null|2/17/15 20:06|                null|Eastern Time (US ...|
# |         negative|US Airways|           32|@USAirways of cou...|       null|2/17/15 20:50|                null|Eastern Time (US ...|
# |         negative|     Delta|           31|STOP. USING.THIS....|       null|2/23/15 10:30|        New York, NY|                null|
# |          neutral|US Airways|           28|@USAirways with t...|       null|2/22/15 11:46|Airports Around T...|Eastern Time (US ...|
# |         positive| Southwest|           22|@SouthwestAir bea...|       null|2/20/15 12:27|        Bellevue, WA|              Hawaii|
# |         negative|     Delta|           22|can you not? RT @...|       null|2/23/15 10:51|         Raleigh, NC|Eastern Time (US ...|
# |         negative|     Delta|           18|Just in case you ...|       null|2/23/15 12:04|Sunny Cali by way...|Pacific Time (US ...|
# |          neutral|     Delta|           15|X____x RT @JetBlu...|       null|2/23/15 11:03|      i'm only human|Eastern Time (US ...|
# |         positive|     Delta|           11|@JetBlue what a g...|       null|2/22/15 12:35|        Palo Alto CA|Pacific Time (US ...|
# |         positive|US Airways|            9|@USAirways Wow un...|       null|2/23/15 10:42|TotalWorldJaxxina...|                null|
# |         positive|     Delta|            8|I know you have a...|       null|2/18/15 20:48|Inquiries: CAA  ...|                null|
# |         negative|    United|            7|@united But I got...|       null|2/17/15 13:58|                null|           Amsterdam|
# |         positive| Southwest|            7|@SouthwestAir y'a...|       null|2/21/15 11:55|       Dallas, Texas|Central Time (US ...|
# |         negative|     Delta|            7|ÛÏ@JetBlue: Our ...|       null|2/23/15 10:29|       New York City|               Quito|
# |          neutral|     Delta|            6|STAHHPPP!!! RT @J...|       null|2/23/15 11:59|Floating in the P...|Pacific Time (US ...|
# |          neutral|     Delta|            6|ÛÏ@JetBlue: Our ...|       null|2/23/15 13:55|                 BWI|Eastern Time (US ...|
# |         positive|     Delta|            6|Hey @JetBlue, tha...|       null|2/18/15 19:39|Inquiries: CAA  ...|                null|
# |         negative|    United|            5|@united @UnitedAp...|       null|2/17/15 14:26|                null|           Amsterdam|
# |         positive|     Delta|            5|This is so smart ...|       null|2/20/15 10:42|                null|Eastern Time (US ...|
# |          neutral|     Delta|            5|ÛÏ@JetBlue: @Kyl...|       null|2/18/15 18:46|            virginia|Atlantic Time (Ca...|
# +-----------------+----------+-------------+--------------------+-----------+-------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Multiple conditions

mySparkDF.filter((mySparkDF["retweet_count"] > 1) &
                 (mySparkDF["airline"] == 'Delta')
                 ).orderBy("retweet_count",ascending=False).show()
# Out:
# +-----------------+-------+-------------+--------------------+-----------+-------------+--------------------+--------------------+
# |airline_sentiment|airline|retweet_count|                text|tweet_coord|tweet_created|      tweet_location|       user_timezone|
# +-----------------+-------+-------------+--------------------+-----------+-------------+--------------------+--------------------+
# |         negative|  Delta|           31|STOP. USING.THIS....|       null|2/23/15 10:30|        New York, NY|                null|
# |         negative|  Delta|           22|can you not? RT @...|       null|2/23/15 10:51|         Raleigh, NC|Eastern Time (US ...|
# |         negative|  Delta|           18|Just in case you ...|       null|2/23/15 12:04|Sunny Cali by way...|Pacific Time (US ...|
# |          neutral|  Delta|           15|X____x RT @JetBlu...|       null|2/23/15 11:03|      i'm only human|Eastern Time (US ...|
# |         positive|  Delta|           11|@JetBlue what a g...|       null|2/22/15 12:35|        Palo Alto CA|Pacific Time (US ...|
# |         positive|  Delta|            8|I know you have a...|       null|2/18/15 20:48|Inquiries: CAA  ...|                null|
# |         negative|  Delta|            7|ÛÏ@JetBlue: Our ...|       null|2/23/15 10:29|       New York City|               Quito|
# |          neutral|  Delta|            6|ÛÏ@JetBlue: Our ...|       null|2/23/15 13:55|                 BWI|Eastern Time (US ...|
# |         positive|  Delta|            6|Hey @JetBlue, tha...|       null|2/18/15 19:39|Inquiries: CAA  ...|                null|
# |          neutral|  Delta|            6|STAHHPPP!!! RT @J...|       null|2/23/15 11:59|Floating in the P...|Pacific Time (US ...|
# |          neutral|  Delta|            5|ÛÏ@JetBlue: @Kyl...|       null|2/18/15 18:46|            virginia|Atlantic Time (Ca...|
# |         positive|  Delta|            5|This is so smart ...|       null|2/20/15 10:42|                null|Eastern Time (US ...|
# |          neutral|  Delta|            4|*On the brink of ...|       null|2/23/15 11:14|                 DMV|Central Time (US ...|
# |         positive|  Delta|            4|It really is nice...|       null|2/18/15 16:43|Inquiries: CAA  ...|                null|
# |         positive|  Delta|            4|@JetBlue shows us...|       null|2/23/15 12:05|                null|              Alaska|
# |          neutral|  Delta|            3|@JetBlue wants Cu...|       null|2/23/15 23:21| Southern California|Pacific Time (US ...|
# |          neutral|  Delta|            3|Why lord whyÛÏ@J...|       null|2/23/15 12:27| D(MD)V Ïöü NY...|Eastern Time (US ...|
# |         negative|  Delta|            3|No no no bad airl...|       null|2/23/15 11:04|In your liquor ca...|Central Time (US ...|
# |         positive|  Delta|            3|@NinaDavuluri We ...|       null|2/19/15 18:44|       1-800-JETBLUE|Eastern Time (US ...|
# |          neutral|  Delta|            3|@JetBlue id appre...|       null|2/22/15 17:20|     Los Angeles, CA|             Arizona|
# +-----------------+-------+-------------+--------------------+-----------+-------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# Spark dataframe can be converted to Pandas dataframe

myPandasDF = mySparkDF.toPandas()
type(myPandasDF)
# Out:
# pandas.core.frame.DataFrame

# %%
# Create a SQL temp view from the dataframe

mySparkDF.createOrReplaceTempView("airlineSentiment")

# %%
# Find out which tables are available in this Spark session

spark.catalog.listTables()
# Out:
# [Table(name='airlineSentiment', database=None, description=None, tableType='TEMPORARY', isTemporary=True)]

# %%
# Now able to use explicit SQL queries

spark.sql("SELECT * FROM airlineSentiment ORDER BY retweet_count DESC")
# Out:
# +-----------------+----------+-------------+--------------------+-----------+-------------+--------------------+--------------------+
# |airline_sentiment|   airline|retweet_count|                text|tweet_coord|tweet_created|      tweet_location|       user_timezone|
# +-----------------+----------+-------------+--------------------+-----------+-------------+--------------------+--------------------+
# |         negative|US Airways|           44|@USAirways 5 hr f...|       null|2/17/15 20:06|                null|Eastern Time (US ...|
# |         negative|US Airways|           32|@USAirways of cou...|       null|2/17/15 20:50|                null|Eastern Time (US ...|
# |         negative|     Delta|           31|STOP. USING.THIS....|       null|2/23/15 10:30|        New York, NY|                null|
# |          neutral|US Airways|           28|@USAirways with t...|       null|2/22/15 11:46|Airports Around T...|Eastern Time (US ...|
# |         positive| Southwest|           22|@SouthwestAir bea...|       null|2/20/15 12:27|        Bellevue, WA|              Hawaii|
# |         negative|     Delta|           22|can you not? RT @...|       null|2/23/15 10:51|         Raleigh, NC|Eastern Time (US ...|
# |         negative|     Delta|           18|Just in case you ...|       null|2/23/15 12:04|Sunny Cali by way...|Pacific Time (US ...|
# |          neutral|     Delta|           15|X____x RT @JetBlu...|       null|2/23/15 11:03|      i'm only human|Eastern Time (US ...|
# |         positive|     Delta|           11|@JetBlue what a g...|       null|2/22/15 12:35|        Palo Alto CA|Pacific Time (US ...|
# |         positive|US Airways|            9|@USAirways Wow un...|       null|2/23/15 10:42|TotalWorldJaxxina...|                null|
# |         positive|     Delta|            8|I know you have a...|       null|2/18/15 20:48|Inquiries: CAA  ...|                null|
# |         negative|     Delta|            7|ÛÏ@JetBlue: Our ...|       null|2/23/15 10:29|       New York City|               Quito|
# |         negative|    United|            7|@united But I got...|       null|2/17/15 13:58|                null|           Amsterdam|
# |         positive| Southwest|            7|@SouthwestAir y'a...|       null|2/21/15 11:55|       Dallas, Texas|Central Time (US ...|
# |          neutral|     Delta|            6|STAHHPPP!!! RT @J...|       null|2/23/15 11:59|Floating in the P...|Pacific Time (US ...|
# |         positive|     Delta|            6|Hey @JetBlue, tha...|       null|2/18/15 19:39|Inquiries: CAA  ...|                null|
# |          neutral|     Delta|            6|ÛÏ@JetBlue: Our ...|       null|2/23/15 13:55|                 BWI|Eastern Time (US ...|
# |          neutral|     Delta|            5|ÛÏ@JetBlue: @Kyl...|       null|2/18/15 18:46|            virginia|Atlantic Time (Ca...|
# |         negative|    United|            5|@united @UnitedAp...|       null|2/17/15 14:26|                null|           Amsterdam|
# |         positive|     Delta|            5|This is so smart ...|       null|2/20/15 10:42|                null|Eastern Time (US ...|
# +-----------------+----------+-------------+--------------------+-----------+-------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### <font color=blue>Upload the file "titanic_train.csv" to the runtime</font>

# %% [markdown]
# ### <font color=blue>Use PySpark dataframe operations to get information for all male passengers with age 50 and above</font>

# %%
# First load the data (be sure it is uploaded in the runtime)
titanic_train = spark.read.csv('titanic_train.csv', header = True, inferSchema=True)

# Use multiple conditions to get the information required
titanic_train.filter((titanic_train["Age"] >= 50) &
                     (titanic_train["Sex"] == 'male')
                     ).show()
# Out:
# +-----------+--------+------+--------------------+----+----+-----+-----+-----------+-------+-----+--------+
# |PassengerId|Survived|Pclass|                Name| Sex| Age|SibSp|Parch|     Ticket|   Fare|Cabin|Embarked|
# +-----------+--------+------+--------------------+----+----+-----+-----+-----------+-------+-----+--------+
# |          7|       0|     1|McCarthy, Mr. Tim...|male|54.0|    0|    0|      17463|51.8625|  E46|       S|
# |         34|       0|     2|Wheadon, Mr. Edwa...|male|66.0|    0|    0| C.A. 24579|   10.5| null|       S|
# |         55|       0|     1|Ostby, Mr. Engelh...|male|65.0|    0|    1|     113509|61.9792|  B30|       C|
# |         95|       0|     3|   Coxon, Mr. Daniel|male|59.0|    0|    0|     364500|   7.25| null|       S|
# |         97|       0|     1|Goldschmidt, Mr. ...|male|71.0|    0|    0|   PC 17754|34.6542|   A5|       C|
# |        117|       0|     3|Connors, Mr. Patrick|male|70.5|    0|    0|     370369|   7.75| null|       Q|
# |        125|       0|     1|White, Mr. Perciv...|male|54.0|    0|    1|      35281|77.2875|  D26|       S|
# |        151|       0|     2|Bateman, Rev. Rob...|male|51.0|    0|    0|S.O.P. 1166| 12.525| null|       S|
# |        153|       0|     3|    Meo, Mr. Alfonzo|male|55.5|    0|    0| A.5. 11206|   8.05| null|       S|
# |        156|       0|     1|Williams, Mr. Cha...|male|51.0|    0|    1|   PC 17597|61.3792| null|       C|
# |        171|       0|     1|Van der hoef, Mr....|male|61.0|    0|    0|     111240|   33.5|  B19|       S|
# |        175|       0|     1|Smith, Mr. James ...|male|56.0|    0|    0|      17764|30.6958|   A7|       C|
# |        223|       0|     3|Green, Mr. George...|male|51.0|    0|    0|      21440|   8.05| null|       S|
# |        233|       0|     2|Sjostedt, Mr. Ern...|male|59.0|    0|    0|     237442|   13.5| null|       S|
# |        250|       0|     2|Carter, Rev. Erne...|male|54.0|    1|    0|     244252|   26.0| null|       S|
# |        253|       0|     1|Stead, Mr. Willia...|male|62.0|    0|    0|     113514|  26.55|  C87|       S|
# |        263|       0|     1|   Taussig, Mr. Emil|male|52.0|    1|    1|     110413|  79.65|  E67|       S|
# |        281|       0|     3|    Duane, Mr. Frank|male|65.0|    0|    0|     336439|   7.75| null|       Q|
# |        318|       0|     2|Moraweck, Dr. Ernest|male|54.0|    0|    0|      29011|   14.0| null|       S|
# |        327|       0|     3|Nysveen, Mr. Joha...|male|61.0|    0|    0|     345364| 6.2375| null|       S|
# +-----------+--------+------+--------------------+----+----+-----+-----+-----------+-------+-----+--------+
# only showing top 20 rows

# %% [markdown]
# ### <font color=blue>Use SQL statements to get information for the oldest passenger in first class</font>

# %%
# Create a SQL temp view from the dataframe
titanic_train.createOrReplaceTempView("titanicTable")

# Use SQL query to retrieve the information
spark.sql("SELECT * FROM titanicTable WHERE Pclass = 1 ORDER BY Age DESC")
# Out:
# +-----------+--------+------+--------------------+------+----+-----+-----+---------+--------+-----------+--------+
# |PassengerId|Survived|Pclass|                Name|   Sex| Age|SibSp|Parch|   Ticket|    Fare|      Cabin|Embarked|
# +-----------+--------+------+--------------------+------+----+-----+-----+---------+--------+-----------+--------+
# |        631|       1|     1|Barkworth, Mr. Al...|  male|80.0|    0|    0|    27042|    30.0|        A23|       S|
# |        494|       0|     1|Artagaveytia, Mr....|  male|71.0|    0|    0| PC 17609| 49.5042|       null|       C|
# |         97|       0|     1|Goldschmidt, Mr. ...|  male|71.0|    0|    0| PC 17754| 34.6542|         A5|       C|
# |        746|       0|     1|Crosby, Capt. Edw...|  male|70.0|    1|    1|WE/P 5735|    71.0|        B22|       S|
# |         55|       0|     1|Ostby, Mr. Engelh...|  male|65.0|    0|    1|   113509| 61.9792|        B30|       C|
# |        457|       0|     1|Millet, Mr. Franc...|  male|65.0|    0|    0|    13509|   26.55|        E38|       S|
# |        439|       0|     1|   Fortune, Mr. Mark|  male|64.0|    1|    4|    19950|   263.0|C23 C25 C27|       S|
# |        546|       0|     1|Nicholson, Mr. Ar...|  male|64.0|    0|    0|      693|    26.0|       null|       S|
# |        276|       1|     1|Andrews, Miss. Ko...|female|63.0|    1|    0|    13502| 77.9583|         D7|       S|
# |        830|       1|     1|Stone, Mrs. Georg...|female|62.0|    0|    0|   113572|    80.0|        B28|    null|
# |        556|       0|     1|  Wright, Mr. George|  male|62.0|    0|    0|   113807|   26.55|       null|       S|
# |        253|       0|     1|Stead, Mr. Willia...|  male|62.0|    0|    0|   113514|   26.55|        C87|       S|
# |        171|       0|     1|Van der hoef, Mr....|  male|61.0|    0|    0|   111240|    33.5|        B19|       S|
# |        626|       0|     1|Sutton, Mr. Frede...|  male|61.0|    0|    0|    36963| 32.3208|        D50|       S|
# |        367|       1|     1|Warren, Mrs. Fran...|female|60.0|    1|    0|   110813|   75.25|        D37|       C|
# |        588|       1|     1|Frolicher-Stehli,...|  male|60.0|    1|    1|    13567|    79.2|        B41|       C|
# |        695|       0|     1|     Weir, Col. John|  male|60.0|    0|    0|   113800|   26.55|       null|       S|
# |        269|       1|     1|Graham, Mrs. Will...|female|58.0|    0|    1| PC 17582|153.4625|       C125|       S|
# |        196|       1|     1|Lurette, Miss. Elise|female|58.0|    0|    0| PC 17569|146.5208|        B80|       C|
# |        488|       0|     1|Kent, Mr. Edward ...|  male|58.0|    0|    0|    11771|    29.7|        B37|       C|
# +-----------+--------+------+--------------------+------+----+-----+-----+---------+--------+-----------+--------+
# only showing top 20 rows
